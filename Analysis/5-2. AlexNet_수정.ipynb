# %% [markdown]
# # - AlexNet

# %%
import os, glob
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, MaxPooling2D, Conv2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import EarlyStopping
from keras import backend as K

# %%
img_dir = 'data/Images3'
categories = os.listdir(img_dir)
num_classes = len(categories)

# %%
image_w = 224
image_h = 224

# %%
X = []
y = []

for index, breed in enumerate(categories):
    label = [0 for i in range(num_classes)]
    label[index] = 1

    image_dir = img_dir + "/" + breed
    files = glob.glob(image_dir+"/*.jpg")
    print(index, ")", breed, " 파일 길이 : ", len(files))
    for i, f in enumerate(files):
        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((image_w, image_h))
        data = np.asarray(img)

        X.append(data)
        y.append(label)
# Out:
# 0 ) n02085620-Chihuahua  파일 길이 :  152
# 1 ) n02085782-Japanese_spaniel  파일 길이 :  185
# 2 ) n02085936-Maltese_dog  파일 길이 :  252
# 3 ) n02086079-Pekinese  파일 길이 :  149
# 4 ) n02086240-Shih-Tzu  파일 길이 :  214
# 5 ) n02086646-Blenheim_spaniel  파일 길이 :  188
# 6 ) n02086910-papillon  파일 길이 :  196
# 7 ) n02088364-beagle  파일 길이 :  195
# 8 ) n02088466-bloodhound  파일 길이 :  187
# 9 ) n02089078-black-and-tan_coonhound  파일 길이 :  159
# 10 ) n02089867-Walker_hound  파일 길이 :  153
# 11 ) n02089973-English_foxhound  파일 길이 :  157
# 12 ) n02091032-Italian_greyhound  파일 길이 :  182
# 13 ) n02091134-whippet  파일 길이 :  187
# 14 ) n02093256-Staffordshire_bullterrier  파일 길이 :  155
# 15 ) n02093647-Bedlington_terrier  파일 길이 :  182
# 16 ) n02094258-Norwich_terrier  파일 길이 :  185
# 17 ) n02094433-Yorkshire_terrier  파일 길이 :  164
# 18 ) n02096294-Australian_terrier  파일 길이 :  196
# 19 ) n02096585-Boston_bull  파일 길이 :  182
# 20 ) n02097047-miniature_schnauzer  파일 길이 :  154
# 21 ) n02097209-standard_schnauzer  파일 길이 :  155
# 22 ) n02097658-silky_terrier  파일 길이 :  183
# 23 ) n02098286-West_Highland_white_terrier  파일 길이 :  169
# 24 ) n02098413-Lhasa  파일 길이 :  186
# 25 ) n02099601-golden_retriever  파일 길이 :  150
# 26 ) n02099712-Labrador_retriever  파일 길이 :  171
# 27 ) n02100583-vizsla  파일 길이 :  154
# 28 ) n02100735-English_setter  파일 길이 :  161
# 29 ) n02102177-Welsh_springer_spaniel  파일 길이 :  150
# 30 ) n02102318-cocker_spaniel  파일 길이 :  159
# 31 ) n02104029-kuvasz  파일 길이 :  150
# 32 ) n02105162-malinois  파일 길이 :  150
# 33 ) n02105855-Shetland_sheepdog  파일 길이 :  157
# 34 ) n02106030-collie  파일 길이 :  153
# 35 ) n02106166-Border_collie  파일 길이 :  150
# 36 ) n02106550-Rottweiler  파일 길이 :  152
# 37 ) n02106662-German_shepherd  파일 길이 :  152
# 38 ) n02107142-Doberman  파일 길이 :  150
# 39 ) n02107312-miniature_pinscher  파일 길이 :  184
# 40 ) n02108089-boxer  파일 길이 :  151
# 41 ) n02108551-Tibetan_mastiff  파일 길이 :  152
# 42 ) n02108915-French_bulldog  파일 길이 :  159
# 43 ) n02109047-Great_Dane  파일 길이 :  156
# 44 ) n02109525-Saint_Bernard  파일 길이 :  170
# 45 ) n02109961-Eskimo_dog  파일 길이 :  150
# 46 ) n02110063-malamute  파일 길이 :  178
# 47 ) n02110185-Siberian_husky  파일 길이 :  192
# 48 ) n02110958-pug  파일 길이 :  200
# 49 ) n02111889-Samoyed  파일 길이 :  218
# 50 ) n02112018-Pomeranian  파일 길이 :  219
# 51 ) n02112137-chow  파일 길이 :  196
# 52 ) n02113023-Pembroke  파일 길이 :  181
# 53 ) n02113186-Cardigan  파일 길이 :  155
# 54 ) n02113624-toy_poodle  파일 길이 :  151
# 55 ) n02113712-miniature_poodle  파일 길이 :  155
# 56 ) n02113799-standard_poodle  파일 길이 :  159
# 57 ) n02113980-bichon_frise  파일 길이 :  231
# 58 ) n02113981-shiba_inu  파일 길이 :  225
# 59 ) n02113982-cane_corso  파일 길이 :  224
# 60 ) n02113983-miniature_dachshund  파일 길이 :  162
# 61 ) n02113984-akita  파일 길이 :  217
# 62 ) n02113985-jindodog  파일 길이 :  186
# 63 ) n02113986-coton_de_tulear  파일 길이 :  211
# 64 ) n02113987-spitz  파일 길이 :  210

# %%
X = np.array(X)
y = np.array(y)

# %%
n = np.arange(X.shape[0]) # 데이터 셔플링
np.random.seed(0)
np.random.shuffle(n)

# %%
X = X[n]
y = y[n]

# %%
print("Images shape after shuffling = ",X.shape,"\nLabels shape after shuffling = ",y.shape)
# Out:
# Images shape after shuffling =  (11418, 224, 224, 3)
# Labels shape after shuffling =  (11418, 65)

# %%
# 정규화
X = X.astype(np.float32)
y = y.astype(np.int32)
X = X/255.

# %%
# 데이터 분할(train, validate, test)
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.1, random_state=1)

# %%
print("x_train shape = ",x_train.shape)
print("y_train shape = ",y_train.shape)

print("\nx_val shape = ",x_val.shape)
print("y_val shape = ",y_val.shape)

print("\nx_test shape = ",x_test.shape)
print("y_test shape = ",y_test.shape)
# Out:
# x_train shape =  (8220, 224, 224, 3)
# y_train shape =  (8220, 65)
#
# x_val shape =  (914, 224, 224, 3)
# y_val shape =  (914, 65)
#
# x_test shape =  (2284, 224, 224, 3)
# y_test shape =  (2284, 65)

# %%
model=Sequential()

#1 conv layer
model.add(Conv2D(filters=64,kernel_size=(7,7),strides=(3,3),padding="valid",activation="relu",input_shape=(image_w,image_h,3)))

#1 max pool layer
model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
model.add(BatchNormalization())

#2 conv layer
model.add(Conv2D(filters=128,kernel_size=(5,5),strides=(1,1),padding="valid",activation="relu"))

#2 max pool layer
model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
model.add(BatchNormalization())

#3 conv layer
model.add(Conv2D(filters=192,kernel_size=(3,3),strides=(1,1),padding="valid",activation="relu"))

#4 conv layer
model.add(Conv2D(filters=256,kernel_size=(3,3),strides=(1,1),padding="valid",activation="relu"))

#3 max pool layer
model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))

model.add(Flatten())

#1 dense layer
model.add(Dense(2048,input_shape=(image_w,image_h,3),activation="relu"))
model.add(Dropout(0.2))
model.add(BatchNormalization())

#2 dense layer
model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.2))
model.add(BatchNormalization())

#output layer
model.add(Dense(65,activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 73, 73, 64)        9472
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 36, 36, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 36, 36, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 128)       204928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 15, 15, 128)       512
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 192)       221376
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 256)       442624
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              13109248
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2048)              8192
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_2 (Dense)              (None, 65)                66625
# =================================================================
# Total params: 16,165,505
# Trainable params: 16,158,977
# Non-trainable params: 6,528
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
K.set_value(model.optimizer.learning_rate, 0.001)

# %%
history = model.fit(x_train, y_train, epochs=100, validation_data=(x_val, y_val), shuffle=True)
# Out:
# Epoch 1/100
# 257/257 [==============================] - 177s 690ms/step - loss: 4.4362 - accuracy: 0.0471 - val_loss: 5.0346 - val_accuracy: 0.0438
# Epoch 2/100
# 257/257 [==============================] - 177s 688ms/step - loss: 4.0925 - accuracy: 0.0659 - val_loss: 4.0546 - val_accuracy: 0.0689
# Epoch 3/100
# 257/257 [==============================] - 175s 680ms/step - loss: 4.0040 - accuracy: 0.0807 - val_loss: 7.7800 - val_accuracy: 0.0328
# Epoch 4/100
# 257/257 [==============================] - 173s 675ms/step - loss: 4.0236 - accuracy: 0.0687 - val_loss: 4.6366 - val_accuracy: 0.0591
# Epoch 5/100
# 257/257 [==============================] - 174s 675ms/step - loss: 3.8601 - accuracy: 0.0847 - val_loss: 3.8461 - val_accuracy: 0.0744
# Epoch 6/100
# 257/257 [==============================] - 174s 676ms/step - loss: 3.8174 - accuracy: 0.0979 - val_loss: 5.5851 - val_accuracy: 0.0416
# Epoch 7/100
# 257/257 [==============================] - 173s 675ms/step - loss: 3.7961 - accuracy: 0.0892 - val_loss: 3.9153 - val_accuracy: 0.0853
# Epoch 8/100
# 257/257 [==============================] - 173s 673ms/step - loss: 3.6368 - accuracy: 0.1163 - val_loss: 5.2925 - val_accuracy: 0.0416
# Epoch 9/100
# 257/257 [==============================] - 173s 674ms/step - loss: 3.6076 - accuracy: 0.1153 - val_loss: 3.9183 - val_accuracy: 0.0821
# Epoch 10/100
# 257/257 [==============================] - 173s 675ms/step - loss: 3.5186 - accuracy: 0.1266 - val_loss: 75.6042 - val_accuracy: 0.0580
# Epoch 11/100
# 257/257 [==============================] - 172s 671ms/step - loss: 3.4901 - accuracy: 0.1229 - val_loss: 4.3555 - val_accuracy: 0.0722
# Epoch 12/100
# 257/257 [==============================] - 173s 675ms/step - loss: 3.7898 - accuracy: 0.0936 - val_loss: 9.8377 - val_accuracy: 0.0492
# Epoch 13/100
# 257/257 [==============================] - 174s 678ms/step - loss: 3.7087 - accuracy: 0.0994 - val_loss: 11.8206 - val_accuracy: 0.0711
# Epoch 14/100
# 257/257 [==============================] - 173s 674ms/step - loss: 3.5312 - accuracy: 0.1185 - val_loss: 7.6655 - val_accuracy: 0.1247
# Epoch 15/100
# 257/257 [==============================] - 174s 675ms/step - loss: 3.3983 - accuracy: 0.1403 - val_loss: 4.2032 - val_accuracy: 0.0941
# Epoch 16/100
# 257/257 [==============================] - 173s 672ms/step - loss: 3.3915 - accuracy: 0.1353 - val_loss: 4.5088 - val_accuracy: 0.0908
# Epoch 17/100
# 257/257 [==============================] - 173s 672ms/step - loss: 3.3907 - accuracy: 0.1404 - val_loss: 5.3093 - val_accuracy: 0.0372
# Epoch 18/100
# 257/257 [==============================] - 174s 677ms/step - loss: 3.3127 - accuracy: 0.1527 - val_loss: 4.7777 - val_accuracy: 0.1127
# Epoch 19/100
# 257/257 [==============================] - 173s 674ms/step - loss: 3.2073 - accuracy: 0.1735 - val_loss: 14.8357 - val_accuracy: 0.0963
# Epoch 20/100
# 257/257 [==============================] - 174s 675ms/step - loss: 3.2913 - accuracy: 0.1578 - val_loss: 17.1686 - val_accuracy: 0.0941
# Epoch 21/100
# 257/257 [==============================] - 173s 674ms/step - loss: 3.1579 - accuracy: 0.1777 - val_loss: 7.2977 - val_accuracy: 0.0295
# Epoch 22/100
# 257/257 [==============================] - 173s 673ms/step - loss: 3.1095 - accuracy: 0.1882 - val_loss: 94.7625 - val_accuracy: 0.1007
# Epoch 23/100
# 257/257 [==============================] - 174s 678ms/step - loss: 3.0664 - accuracy: 0.2001 - val_loss: 4.2230 - val_accuracy: 0.0777
# Epoch 24/100
# 257/257 [==============================] - 173s 673ms/step - loss: 3.2421 - accuracy: 0.1697 - val_loss: 9.2781 - val_accuracy: 0.1269
# Epoch 25/100
# 257/257 [==============================] - 173s 673ms/step - loss: 3.4415 - accuracy: 0.1391 - val_loss: 120.7671 - val_accuracy: 0.0569
# Epoch 26/100
# 257/257 [==============================] - 174s 675ms/step - loss: 3.3067 - accuracy: 0.1541 - val_loss: 3.6922 - val_accuracy: 0.1214
# Epoch 27/100
# 257/257 [==============================] - 173s 673ms/step - loss: 3.1066 - accuracy: 0.1903 - val_loss: 10.1842 - val_accuracy: 0.1247
# Epoch 28/100
# 257/257 [==============================] - 173s 674ms/step - loss: 3.3859 - accuracy: 0.1466 - val_loss: 8.9492 - val_accuracy: 0.1269
# Epoch 29/100
# 257/257 [==============================] - 174s 676ms/step - loss: 3.1719 - accuracy: 0.1765 - val_loss: 105.3214 - val_accuracy: 0.1236
# Epoch 30/100
# 257/257 [==============================] - 174s 677ms/step - loss: 3.2021 - accuracy: 0.1775 - val_loss: 25.5267 - val_accuracy: 0.1050
# Epoch 31/100
# 257/257 [==============================] - 175s 681ms/step - loss: 3.3563 - accuracy: 0.1496 - val_loss: 26.6353 - val_accuracy: 0.1116
# Epoch 32/100
# 257/257 [==============================] - 174s 678ms/step - loss: 3.1804 - accuracy: 0.1748 - val_loss: 57.2140 - val_accuracy: 0.1214
# Epoch 33/100
# 257/257 [==============================] - 174s 677ms/step - loss: 3.0630 - accuracy: 0.2027 - val_loss: 28.5157 - val_accuracy: 0.1291
# Epoch 34/100
# 257/257 [==============================] - 174s 678ms/step - loss: 3.5147 - accuracy: 0.1226 - val_loss: 41.0211 - val_accuracy: 0.0963
# Epoch 35/100
# 257/257 [==============================] - 174s 678ms/step - loss: 3.2285 - accuracy: 0.1685 - val_loss: 81.6220 - val_accuracy: 0.1007
# Epoch 36/100
# 257/257 [==============================] - 175s 680ms/step - loss: 3.0821 - accuracy: 0.1972 - val_loss: 94.0404 - val_accuracy: 0.1291
# Epoch 37/100
# 257/257 [==============================] - 174s 677ms/step - loss: 3.1671 - accuracy: 0.1818 - val_loss: 73.5260 - val_accuracy: 0.1138
# Epoch 38/100
# 257/257 [==============================] - 176s 684ms/step - loss: 3.0650 - accuracy: 0.1959 - val_loss: 78.0013 - val_accuracy: 0.1335
# Epoch 39/100
# 257/257 [==============================] - 174s 677ms/step - loss: 2.9779 - accuracy: 0.2195 - val_loss: 68.9754 - val_accuracy: 0.1171
# Epoch 40/100
# 257/257 [==============================] - 175s 680ms/step - loss: 2.9362 - accuracy: 0.2189 - val_loss: 77.4049 - val_accuracy: 0.1368
# Epoch 41/100
# 257/257 [==============================] - 175s 680ms/step - loss: 2.8973 - accuracy: 0.2315 - val_loss: 33.6998 - val_accuracy: 0.1379
# Epoch 42/100
# 257/257 [==============================] - 176s 684ms/step - loss: 2.9306 - accuracy: 0.2240 - val_loss: 15.0085 - val_accuracy: 0.1116
# Epoch 43/100
# 257/257 [==============================] - 175s 680ms/step - loss: 2.8404 - accuracy: 0.2405 - val_loss: 94.5533 - val_accuracy: 0.1258
# Epoch 44/100
# 257/257 [==============================] - 175s 680ms/step - loss: 2.7796 - accuracy: 0.2579 - val_loss: 68.8994 - val_accuracy: 0.1149
# Epoch 45/100
# 257/257 [==============================] - 176s 684ms/step - loss: 2.7204 - accuracy: 0.2682 - val_loss: 34.8762 - val_accuracy: 0.1280
# Epoch 46/100
# 257/257 [==============================] - 174s 677ms/step - loss: 2.6362 - accuracy: 0.2898 - val_loss: 393.6380 - val_accuracy: 0.0700
# Epoch 47/100
# 257/257 [==============================] - 174s 676ms/step - loss: 2.7485 - accuracy: 0.2560 - val_loss: 240.2083 - val_accuracy: 0.1072
# Epoch 48/100
# 257/257 [==============================] - 175s 682ms/step - loss: 3.7577 - accuracy: 0.1016 - val_loss: 4.1340 - val_accuracy: 0.0646
# Epoch 49/100
# 257/257 [==============================] - 176s 684ms/step - loss: 3.7046 - accuracy: 0.0861 - val_loss: 4.8632 - val_accuracy: 0.0821
# Epoch 50/100
# 257/257 [==============================] - 176s 684ms/step - loss: 3.5204 - accuracy: 0.1167 - val_loss: 8.2877 - val_accuracy: 0.0952
# Epoch 51/100
# 257/257 [==============================] - 175s 679ms/step - loss: 3.3630 - accuracy: 0.1366 - val_loss: 20.3107 - val_accuracy: 0.0974
# Epoch 52/100
# 257/257 [==============================] - 175s 680ms/step - loss: 3.3303 - accuracy: 0.1554 - val_loss: 10.2905 - val_accuracy: 0.0777
# Epoch 53/100
# 257/257 [==============================] - 175s 679ms/step - loss: 3.1974 - accuracy: 0.1720 - val_loss: 18.2545 - val_accuracy: 0.1160
# Epoch 54/100
# 257/257 [==============================] - 175s 680ms/step - loss: 3.0658 - accuracy: 0.1989 - val_loss: 32.0243 - val_accuracy: 0.1302
# Epoch 55/100
# 257/257 [==============================] - 175s 681ms/step - loss: 2.9631 - accuracy: 0.2202 - val_loss: 7.1138 - val_accuracy: 0.1127
# Epoch 56/100
# 257/257 [==============================] - 175s 679ms/step - loss: 2.9071 - accuracy: 0.2288 - val_loss: 105.4135 - val_accuracy: 0.1214
# Epoch 57/100
# 257/257 [==============================] - 174s 678ms/step - loss: 2.8398 - accuracy: 0.2462 - val_loss: 157.7544 - val_accuracy: 0.1400
# Epoch 58/100
# 257/257 [==============================] - 174s 675ms/step - loss: 2.7689 - accuracy: 0.2523 - val_loss: 375.2304 - val_accuracy: 0.1280
# Epoch 59/100
# 257/257 [==============================] - 175s 679ms/step - loss: 2.6974 - accuracy: 0.2764 - val_loss: 176.8466 - val_accuracy: 0.1422
# Epoch 60/100
# 257/257 [==============================] - 175s 682ms/step - loss: 2.6516 - accuracy: 0.2830 - val_loss: 125.6185 - val_accuracy: 0.1291
# Epoch 61/100
# 257/257 [==============================] - 174s 678ms/step - loss: 2.6237 - accuracy: 0.2938 - val_loss: 92.2781 - val_accuracy: 0.1193
# Epoch 62/100
# 257/257 [==============================] - 175s 681ms/step - loss: 2.5775 - accuracy: 0.2909 - val_loss: 93.9889 - val_accuracy: 0.1368
# Epoch 63/100
# 257/257 [==============================] - 175s 681ms/step - loss: 2.5371 - accuracy: 0.3066 - val_loss: 49.6290 - val_accuracy: 0.1193
# Epoch 64/100
# 257/257 [==============================] - 175s 681ms/step - loss: 2.4564 - accuracy: 0.3251 - val_loss: 71.2649 - val_accuracy: 0.1400
# Epoch 65/100
# 257/257 [==============================] - 175s 679ms/step - loss: 2.4472 - accuracy: 0.3214 - val_loss: 62.8076 - val_accuracy: 0.1291
# Epoch 66/100
# 257/257 [==============================] - 175s 680ms/step - loss: 2.4133 - accuracy: 0.3263 - val_loss: 39.3513 - val_accuracy: 0.1433
# Epoch 67/100
# 257/257 [==============================] - 175s 681ms/step - loss: 2.6364 - accuracy: 0.2876 - val_loss: 154.6807 - val_accuracy: 0.1368
# Epoch 68/100
# 257/257 [==============================] - 174s 677ms/step - loss: 2.4367 - accuracy: 0.3303 - val_loss: 528.4995 - val_accuracy: 0.0460
# Epoch 69/100
# 257/257 [==============================] - 175s 682ms/step - loss: 2.5637 - accuracy: 0.3010 - val_loss: 29.0591 - val_accuracy: 0.1466
# Epoch 70/100
# 257/257 [==============================] - 175s 681ms/step - loss: 2.3665 - accuracy: 0.3427 - val_loss: 83.4115 - val_accuracy: 0.1400
# Epoch 71/100
# 257/257 [==============================] - 175s 680ms/step - loss: 2.6263 - accuracy: 0.2925 - val_loss: 99.2417 - val_accuracy: 0.1160
# Epoch 72/100
# 257/257 [==============================] - 175s 683ms/step - loss: 2.5293 - accuracy: 0.3096 - val_loss: 15.9955 - val_accuracy: 0.1302
# Epoch 73/100
# 257/257 [==============================] - 174s 678ms/step - loss: 2.3308 - accuracy: 0.3501 - val_loss: 84.1212 - val_accuracy: 0.1532
# Epoch 74/100
# 257/257 [==============================] - 175s 680ms/step - loss: 2.2926 - accuracy: 0.3586 - val_loss: 7.3364 - val_accuracy: 0.1324
# Epoch 75/100
# 257/257 [==============================] - 174s 677ms/step - loss: 2.2041 - accuracy: 0.3859 - val_loss: 52.5804 - val_accuracy: 0.1357
# Epoch 76/100
# 257/257 [==============================] - 175s 683ms/step - loss: 2.1665 - accuracy: 0.3886 - val_loss: 297.4759 - val_accuracy: 0.1357
# Epoch 77/100
# 257/257 [==============================] - 174s 678ms/step - loss: 2.1314 - accuracy: 0.4032 - val_loss: 700.6899 - val_accuracy: 0.1028
# Epoch 78/100
# 257/257 [==============================] - 174s 679ms/step - loss: 2.0586 - accuracy: 0.4167 - val_loss: 271.8323 - val_accuracy: 0.1291
# Epoch 79/100
# 257/257 [==============================] - 174s 678ms/step - loss: 2.2898 - accuracy: 0.3726 - val_loss: 535.7979 - val_accuracy: 0.1050
# Epoch 80/100
# 257/257 [==============================] - 174s 677ms/step - loss: 2.1499 - accuracy: 0.3926 - val_loss: 29.3213 - val_accuracy: 0.1433
# Epoch 81/100
# 257/257 [==============================] - 176s 684ms/step - loss: 2.2330 - accuracy: 0.3875 - val_loss: 266.8965 - val_accuracy: 0.0405
# Epoch 82/100
# 257/257 [==============================] - 175s 682ms/step - loss: 2.3110 - accuracy: 0.3521 - val_loss: 12.7273 - val_accuracy: 0.1499
# Epoch 83/100
# 257/257 [==============================] - 175s 681ms/step - loss: 2.2695 - accuracy: 0.3775 - val_loss: 12.8029 - val_accuracy: 0.0350
# Epoch 84/100
# 257/257 [==============================] - 174s 676ms/step - loss: 3.0341 - accuracy: 0.2167 - val_loss: 52.8601 - val_accuracy: 0.1204
# Epoch 85/100
# 257/257 [==============================] - 175s 680ms/step - loss: 2.4317 - accuracy: 0.3271 - val_loss: 36.7840 - val_accuracy: 0.1433
# Epoch 86/100
# 257/257 [==============================] - 175s 682ms/step - loss: 2.2379 - accuracy: 0.3682 - val_loss: 43.0065 - val_accuracy: 0.1521
# Epoch 87/100
# 257/257 [==============================] - 174s 678ms/step - loss: 2.0885 - accuracy: 0.4117 - val_loss: 18.7814 - val_accuracy: 0.1433
# Epoch 88/100
# 257/257 [==============================] - 174s 678ms/step - loss: 2.0101 - accuracy: 0.4277 - val_loss: 3.9035 - val_accuracy: 0.1455
# Epoch 89/100
# 257/257 [==============================] - 175s 679ms/step - loss: 1.9319 - accuracy: 0.4417 - val_loss: 5.4817 - val_accuracy: 0.1565
# Epoch 90/100
# 257/257 [==============================] - 175s 681ms/step - loss: 1.8362 - accuracy: 0.4634 - val_loss: 35.8780 - val_accuracy: 0.1740
# Epoch 91/100
# 257/257 [==============================] - 176s 683ms/step - loss: 1.8344 - accuracy: 0.4689 - val_loss: 43.2415 - val_accuracy: 0.1510
# Epoch 92/100
# 257/257 [==============================] - 174s 678ms/step - loss: 1.7731 - accuracy: 0.4820 - val_loss: 331.3064 - val_accuracy: 0.1444
# Epoch 93/100
# 257/257 [==============================] - 174s 678ms/step - loss: 1.6993 - accuracy: 0.5083 - val_loss: 116.6000 - val_accuracy: 0.1488
# Epoch 94/100
# 257/257 [==============================] - 175s 681ms/step - loss: 1.7040 - accuracy: 0.5004 - val_loss: 86.6427 - val_accuracy: 0.1565
# Epoch 95/100
# 257/257 [==============================] - 175s 682ms/step - loss: 1.6820 - accuracy: 0.5103 - val_loss: 63.3387 - val_accuracy: 0.1532
# Epoch 96/100
# 257/257 [==============================] - 175s 682ms/step - loss: 1.6231 - accuracy: 0.5257 - val_loss: 32.6052 - val_accuracy: 0.1466
# Epoch 97/100
# 257/257 [==============================] - 175s 682ms/step - loss: 1.5834 - accuracy: 0.5363 - val_loss: 30.5548 - val_accuracy: 0.1761
# Epoch 98/100
# 257/257 [==============================] - 174s 677ms/step - loss: 1.5268 - accuracy: 0.5487 - val_loss: 9.7740 - val_accuracy: 0.1772
# Epoch 99/100
# 257/257 [==============================] - 175s 682ms/step - loss: 1.5317 - accuracy: 0.5354 - val_loss: 109.0544 - val_accuracy: 0.1532
# Epoch 100/100
# 257/257 [==============================] - 174s 678ms/step - loss: 1.4440 - accuracy: 0.5715 - val_loss: 89.4113 - val_accuracy: 0.1586

# %%
loss, accuracy = model.evaluate(x_test, y_test)

print('\nLoss: {:.4f}, Acc: {:.4f}'.format(loss, accuracy))
# Out:
# 72/72 [==============================] - 13s 183ms/step - loss: 249.9184 - accuracy: 0.1475
#
# Loss: 249.9184, Acc: 0.1475

# %%
def plot_loss(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc=0)

def plot_acc(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc=0)

# %%
plot_loss(history)
plt.show()

# %%
plot_acc(history)
plt.show()

# %%
predictions = model.predict(x_test)

# %%
plt.figure(1 , figsize = (19 , 10))
n = 0 

for i in range(16):
    n += 1 
    r = np.random.randint( 0, x_test.shape[0], 1)
    
    plt.subplot(4, 4, n)
    plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
    
    plt.imshow(x_test[r[0]])
    plt.title('Actual = {}, \nPredicted = {}'.format(categories[np.argpartition(y_test[r[0]],-1)[-1:][0]] , categories[np.argpartition(predictions[r[0]][y_test[r[0]]],-1)[-1:][0]]))
    plt.xticks([]) , plt.yticks([])

plt.show()

# %% [markdown]
# # - VGGNet(VGG16)

# %%
import os, glob
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

# %%
img_dir = 'dogdataset'
categories = os.listdir(img_dir)
num_classes = len(categories)

# %%
image_w = 224
image_h = 224

# %%
X = []
y = []

for index, breed in enumerate(categories):
    label = [0 for i in range(num_classes)]
    label[index] = 1

    image_dir = img_dir + "/" + breed
    files = glob.glob(image_dir+"/*.jpg")
    print(index, ")", breed, " 파일 길이 : ", len(files))
    for i, f in enumerate(files):
        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((image_w, image_h))
        data = np.asarray(img)

        X.append(data)
        y.append(label)
# Out:
# 0 ) n02085620-Chihuahua  파일 길이 :  152
# 1 ) n02085782-Japanese_spaniel  파일 길이 :  185
# 2 ) n02085936-Maltese_dog  파일 길이 :  252
# 3 ) n02086079-Pekinese  파일 길이 :  149
# 4 ) n02086240-Shih-Tzu  파일 길이 :  214
# 5 ) n02086646-Blenheim_spaniel  파일 길이 :  188
# 6 ) n02086910-papillon  파일 길이 :  196
# 7 ) n02088364-beagle  파일 길이 :  195
# 8 ) n02088466-bloodhound  파일 길이 :  187
# 9 ) n02089078-black-and-tan_coonhound  파일 길이 :  159
# 10 ) n02089867-Walker_hound  파일 길이 :  153
# 11 ) n02089973-English_foxhound  파일 길이 :  157
# 12 ) n02091032-Italian_greyhound  파일 길이 :  182
# 13 ) n02091134-whippet  파일 길이 :  187
# 14 ) n02093256-Staffordshire_bullterrier  파일 길이 :  155
# 15 ) n02093647-Bedlington_terrier  파일 길이 :  182
# 16 ) n02094258-Norwich_terrier  파일 길이 :  185
# 17 ) n02094433-Yorkshire_terrier  파일 길이 :  164
# 18 ) n02096294-Australian_terrier  파일 길이 :  196
# 19 ) n02096585-Boston_bull  파일 길이 :  182
# 20 ) n02097047-miniature_schnauzer  파일 길이 :  154
# 21 ) n02097209-standard_schnauzer  파일 길이 :  155
# 22 ) n02097658-silky_terrier  파일 길이 :  183
# 23 ) n02098286-West_Highland_white_terrier  파일 길이 :  169
# 24 ) n02098413-Lhasa  파일 길이 :  186
# 25 ) n02099601-golden_retriever  파일 길이 :  150
# 26 ) n02099712-Labrador_retriever  파일 길이 :  171
# 27 ) n02100583-vizsla  파일 길이 :  154
# 28 ) n02100735-English_setter  파일 길이 :  161
# 29 ) n02102177-Welsh_springer_spaniel  파일 길이 :  150
# 30 ) n02102318-cocker_spaniel  파일 길이 :  159
# 31 ) n02104029-kuvasz  파일 길이 :  150
# 32 ) n02105162-malinois  파일 길이 :  150
# 33 ) n02105855-Shetland_sheepdog  파일 길이 :  157
# 34 ) n02106030-collie  파일 길이 :  153
# 35 ) n02106166-Border_collie  파일 길이 :  150
# 36 ) n02106550-Rottweiler  파일 길이 :  152
# 37 ) n02106662-German_shepherd  파일 길이 :  152
# 38 ) n02107142-Doberman  파일 길이 :  150
# 39 ) n02107312-miniature_pinscher  파일 길이 :  184
# 40 ) n02108089-boxer  파일 길이 :  151
# 41 ) n02108551-Tibetan_mastiff  파일 길이 :  152
# 42 ) n02108915-French_bulldog  파일 길이 :  159
# 43 ) n02109047-Great_Dane  파일 길이 :  156
# 44 ) n02109525-Saint_Bernard  파일 길이 :  170
# 45 ) n02109961-Eskimo_dog  파일 길이 :  150
# 46 ) n02110063-malamute  파일 길이 :  178
# 47 ) n02110185-Siberian_husky  파일 길이 :  192
# 48 ) n02110958-pug  파일 길이 :  200
# 49 ) n02111889-Samoyed  파일 길이 :  218
# 50 ) n02112018-Pomeranian  파일 길이 :  219
# 51 ) n02112137-chow  파일 길이 :  196
# 52 ) n02113023-Pembroke  파일 길이 :  181
# 53 ) n02113186-Cardigan  파일 길이 :  155
# 54 ) n02113624-toy_poodle  파일 길이 :  151
# 55 ) n02113712-miniature_poodle  파일 길이 :  155
# 56 ) n02113799-standard_poodle  파일 길이 :  159
# 57 ) n02113980-bichon_frise  파일 길이 :  231
# 58 ) n02113981-shiba_inu  파일 길이 :  225
# 59 ) n02113982-cane_corso  파일 길이 :  224
# 60 ) n02113983-miniature_dachshund  파일 길이 :  162
# 61 ) n02113984-akita  파일 길이 :  217
# 62 ) n02113985-jindodog  파일 길이 :  186
# 63 ) n02113986-coton_de_tulear  파일 길이 :  211
# 64 ) n02113987-spitz  파일 길이 :  210

# %%
X = np.array(X)
y = np.array(y)

# %%
n = np.arange(X.shape[0])
np.random.seed(0)
np.random.shuffle(n)

# %%
X = X[n]
y = y[n]

# %%
print("Images shape after shuffling = ",X.shape,"\nLabels shape after shuffling = ",y.shape)
# Out:
# Images shape after shuffling =  (11418, 224, 224, 3)
# Labels shape after shuffling =  (11418, 65)

# %%
X = X.astype(np.float32)
y = y.astype(np.int32)
X = X/255.

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.1, random_state=1)

# %%
print("x_train shape = ",x_train.shape)
print("y_train shape = ",y_train.shape)

print("\nx_val shape = ",x_val.shape)
print("y_val shape = ",y_val.shape)

print("\nx_test shape = ",x_test.shape)
print("y_test shape = ",y_test.shape)
# Out:
# x_train shape =  (8220, 224, 224, 3)
# y_train shape =  (8220, 65)
#
# x_val shape =  (914, 224, 224, 3)
# y_val shape =  (914, 65)
#
# x_test shape =  (2284, 224, 224, 3)
# y_test shape =  (2284, 65)

# %%
model = Sequential()

model.add(ZeroPadding2D((1,1),input_shape=(image_w,image_h,3)))
model.add(Convolution2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(65, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d (ZeroPadding2 (None, 226, 226, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 114, 114, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 58, 58, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 200704)            0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              205521920
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 65)                66625
# =================================================================
# Total params: 205,959,361
# Trainable params: 205,959,361
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=["accuracy"])
K.set_value(model.optimizer.learning_rate, 0.0001)

# %%
early_stopping= EarlyStopping(monitor='val_loss', mode ='min', verbose = 1, patience = 10)
model_checkPoint = ModelCheckpoint('VGGNet.h5', monitor='val_loss', save_best_only = True, mode ='min', verbose = 1)

# %%
history =model.fit(x_train, y_train, epochs=100, validation_data=(x_val, y_val), shuffle=True, batch_size=128, callbacks=[early_stopping, model_checkPoint])
# Out:
# Epoch 1/100
# 65/65 [==============================] - ETA: 0s - loss: 4.1740 - accuracy: 0.0245
# Epoch 00001: val_loss improved from inf to 4.09771, saving model to VGGNet.h5
# 65/65 [==============================] - 773s 12s/step - loss: 4.1740 - accuracy: 0.0245 - val_loss: 4.0977 - val_accuracy: 0.0306
# Epoch 2/100
# 65/65 [==============================] - ETA: 0s - loss: 3.9939 - accuracy: 0.0568
# Epoch 00002: val_loss improved from 4.09771 to 3.86763, saving model to VGGNet.h5
# 65/65 [==============================] - 761s 12s/step - loss: 3.9939 - accuracy: 0.0568 - val_loss: 3.8676 - val_accuracy: 0.0788
# Epoch 3/100
# 65/65 [==============================] - ETA: 0s - loss: 3.7491 - accuracy: 0.0964
# Epoch 00003: val_loss improved from 3.86763 to 3.71489, saving model to VGGNet.h5
# 65/65 [==============================] - 789s 12s/step - loss: 3.7491 - accuracy: 0.0964 - val_loss: 3.7149 - val_accuracy: 0.1138
# Epoch 4/100
# 65/65 [==============================] - ETA: 0s - loss: 3.4853 - accuracy: 0.1496
# Epoch 00004: val_loss improved from 3.71489 to 3.65635, saving model to VGGNet.h5
# 65/65 [==============================] - 810s 12s/step - loss: 3.4853 - accuracy: 0.1496 - val_loss: 3.6564 - val_accuracy: 0.1171
# Epoch 5/100
# 65/65 [==============================] - ETA: 0s - loss: 3.0756 - accuracy: 0.2339
# Epoch 00005: val_loss improved from 3.65635 to 3.58266, saving model to VGGNet.h5
# 65/65 [==============================] - 815s 13s/step - loss: 3.0756 - accuracy: 0.2339 - val_loss: 3.5827 - val_accuracy: 0.1346
# Epoch 6/100
# 65/65 [==============================] - ETA: 0s - loss: 2.5843 - accuracy: 0.3428
# Epoch 00006: val_loss did not improve from 3.58266
# 65/65 [==============================] - 787s 12s/step - loss: 2.5843 - accuracy: 0.3428 - val_loss: 3.6330 - val_accuracy: 0.1346
# Epoch 7/100
# 65/65 [==============================] - ETA: 0s - loss: 2.0409 - accuracy: 0.4729
# Epoch 00007: val_loss did not improve from 3.58266
# 65/65 [==============================] - 774s 12s/step - loss: 2.0409 - accuracy: 0.4729 - val_loss: 3.7414 - val_accuracy: 0.1280
# Epoch 8/100
# 65/65 [==============================] - ETA: 0s - loss: 1.5554 - accuracy: 0.5906
# Epoch 00008: val_loss did not improve from 3.58266
# 65/65 [==============================] - 767s 12s/step - loss: 1.5554 - accuracy: 0.5906 - val_loss: 3.9850 - val_accuracy: 0.1269
# Epoch 9/100
# 65/65 [==============================] - ETA: 0s - loss: 1.1341 - accuracy: 0.6957
# Epoch 00009: val_loss did not improve from 3.58266
# 65/65 [==============================] - 778s 12s/step - loss: 1.1341 - accuracy: 0.6957 - val_loss: 4.2404 - val_accuracy: 0.1171
# Epoch 10/100
# 65/65 [==============================] - ETA: 0s - loss: 0.8407 - accuracy: 0.7746
# Epoch 00010: val_loss did not improve from 3.58266
# 65/65 [==============================] - 766s 12s/step - loss: 0.8407 - accuracy: 0.7746 - val_loss: 4.4487 - val_accuracy: 0.1291
# Epoch 11/100
# 65/65 [==============================] - ETA: 0s - loss: 0.6349 - accuracy: 0.8307
# Epoch 00011: val_loss did not improve from 3.58266
# 65/65 [==============================] - 771s 12s/step - loss: 0.6349 - accuracy: 0.8307 - val_loss: 4.6131 - val_accuracy: 0.1313
# Epoch 12/100
# 65/65 [==============================] - ETA: 0s - loss: 0.4584 - accuracy: 0.8765
# Epoch 00012: val_loss did not improve from 3.58266
# 65/65 [==============================] - 762s 12s/step - loss: 0.4584 - accuracy: 0.8765 - val_loss: 4.7542 - val_accuracy: 0.1368
# Epoch 13/100
# 65/65 [==============================] - ETA: 0s - loss: 0.3627 - accuracy: 0.9064
# Epoch 00013: val_loss did not improve from 3.58266
# 65/65 [==============================] - 797s 12s/step - loss: 0.3627 - accuracy: 0.9064 - val_loss: 4.8664 - val_accuracy: 0.1368
# Epoch 14/100
# 65/65 [==============================] - ETA: 0s - loss: 0.2973 - accuracy: 0.9225
# Epoch 00014: val_loss did not improve from 3.58266
# 65/65 [==============================] - 823s 13s/step - loss: 0.2973 - accuracy: 0.9225 - val_loss: 5.1043 - val_accuracy: 0.1368
# Epoch 15/100
# 65/65 [==============================] - ETA: 0s - loss: 0.2513 - accuracy: 0.9376
# Epoch 00015: val_loss did not improve from 3.58266
# 65/65 [==============================] - 799s 12s/step - loss: 0.2513 - accuracy: 0.9376 - val_loss: 5.2248 - val_accuracy: 0.1313
# Epoch 00015: early stopping

# %%
loss, accuracy = model.evaluate(x_test, y_test)

print('\nLoss: {:.4f}, Acc: {:.4f}'.format(loss, accuracy))
# Out:
# 72/72 [==============================] - 49s 679ms/step - loss: 5.5253 - accuracy: 0.1182
#
# Loss: 5.5253, Acc: 0.1182

# %%
def plot_loss(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc=0)

def plot_acc(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc=0)

# %%
plot_loss(history)
plt.show()

# %%
plot_acc(history)
plt.show()

# %%
predictions = model.predict(x_test)

# %%
plt.figure(1 , figsize = (19 , 10))
n = 0 

for i in range(16):
    n += 1 
    r = np.random.randint( 0, x_test.shape[0], 1)
    
    plt.subplot(4, 4, n)
    plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
    
    plt.imshow(x_test[r[0]])
    plt.title('Actual = {}, \nPredicted = {}'.format(np.argpartition(y_test[r[0]],-1)[-1:] , np.argpartition(predictions[r[0]][y_test[r[0]]],-1)[-1:]))
    plt.xticks([]) , plt.yticks([])

plt.show()

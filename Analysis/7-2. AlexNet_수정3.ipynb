# %% [markdown]
# # - AlexNet

# %%
import os, glob
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, MaxPooling2D, Conv2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img_dir = 'data/Images3'
categories = os.listdir(img_dir)
num_classes = len(categories)

# %%
image_w = 224
image_h = 224

# %%
X = []
y = []

for index, breed in enumerate(categories):
    label = [0 for i in range(num_classes)]
    label[index] = 1

    image_dir = img_dir + "/" + breed
    files = glob.glob(image_dir+"/*.jpg")
    print(index, ")", breed, " 파일 길이 : ", len(files))
    for i, f in enumerate(files):
        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((image_w, image_h))
        data = np.asarray(img)

        X.append(data)
        y.append(label)
# Out:
# 0 ) n02085620-Chihuahua  파일 길이 :  152
# 1 ) n02085782-Japanese_spaniel  파일 길이 :  185
# 2 ) n02085936-Maltese_dog  파일 길이 :  252
# 3 ) n02086079-Pekinese  파일 길이 :  149
# 4 ) n02086240-Shih-Tzu  파일 길이 :  214
# 5 ) n02086646-Blenheim_spaniel  파일 길이 :  188
# 6 ) n02086910-papillon  파일 길이 :  196
# 7 ) n02088364-beagle  파일 길이 :  195
# 8 ) n02088466-bloodhound  파일 길이 :  187
# 9 ) n02089078-black-and-tan_coonhound  파일 길이 :  159
# 10 ) n02089867-Walker_hound  파일 길이 :  153
# 11 ) n02089973-English_foxhound  파일 길이 :  157
# 12 ) n02091032-Italian_greyhound  파일 길이 :  182
# 13 ) n02091134-whippet  파일 길이 :  187
# 14 ) n02093256-Staffordshire_bullterrier  파일 길이 :  155
# 15 ) n02093647-Bedlington_terrier  파일 길이 :  182
# 16 ) n02094258-Norwich_terrier  파일 길이 :  185
# 17 ) n02094433-Yorkshire_terrier  파일 길이 :  164
# 18 ) n02096294-Australian_terrier  파일 길이 :  196
# 19 ) n02096585-Boston_bull  파일 길이 :  182
# 20 ) n02097047-miniature_schnauzer  파일 길이 :  154
# 21 ) n02097209-standard_schnauzer  파일 길이 :  155
# 22 ) n02097658-silky_terrier  파일 길이 :  183
# 23 ) n02098286-West_Highland_white_terrier  파일 길이 :  169
# 24 ) n02098413-Lhasa  파일 길이 :  186
# 25 ) n02099601-golden_retriever  파일 길이 :  150
# 26 ) n02099712-Labrador_retriever  파일 길이 :  171
# 27 ) n02100583-vizsla  파일 길이 :  154
# 28 ) n02100735-English_setter  파일 길이 :  161
# 29 ) n02102177-Welsh_springer_spaniel  파일 길이 :  150
# 30 ) n02102318-cocker_spaniel  파일 길이 :  159
# 31 ) n02104029-kuvasz  파일 길이 :  150
# 32 ) n02105162-malinois  파일 길이 :  150
# 33 ) n02105855-Shetland_sheepdog  파일 길이 :  157
# 34 ) n02106030-collie  파일 길이 :  153
# 35 ) n02106166-Border_collie  파일 길이 :  150
# 36 ) n02106550-Rottweiler  파일 길이 :  152
# 37 ) n02106662-German_shepherd  파일 길이 :  152
# 38 ) n02107142-Doberman  파일 길이 :  150
# 39 ) n02107312-miniature_pinscher  파일 길이 :  184
# 40 ) n02108089-boxer  파일 길이 :  151
# 41 ) n02108551-Tibetan_mastiff  파일 길이 :  152
# 42 ) n02108915-French_bulldog  파일 길이 :  159
# 43 ) n02109047-Great_Dane  파일 길이 :  156
# 44 ) n02109525-Saint_Bernard  파일 길이 :  170
# 45 ) n02109961-Eskimo_dog  파일 길이 :  150
# 46 ) n02110063-malamute  파일 길이 :  178
# 47 ) n02110185-Siberian_husky  파일 길이 :  192
# 48 ) n02110958-pug  파일 길이 :  200
# 49 ) n02111889-Samoyed  파일 길이 :  218
# 50 ) n02112018-Pomeranian  파일 길이 :  219
# 51 ) n02112137-chow  파일 길이 :  196
# 52 ) n02113023-Pembroke  파일 길이 :  181
# 53 ) n02113186-Cardigan  파일 길이 :  155
# 54 ) n02113624-toy_poodle  파일 길이 :  151
# 55 ) n02113712-miniature_poodle  파일 길이 :  155
# 56 ) n02113799-standard_poodle  파일 길이 :  159
# 57 ) n02113980-bichon_frise  파일 길이 :  231
# 58 ) n02113981-shiba_inu  파일 길이 :  225
# 59 ) n02113982-cane_corso  파일 길이 :  224
# 60 ) n02113983-miniature_dachshund  파일 길이 :  162
# 61 ) n02113984-akita  파일 길이 :  217
# 62 ) n02113985-jindodog  파일 길이 :  186
# 63 ) n02113986-coton_de_tulear  파일 길이 :  211
# 64 ) n02113987-spitz  파일 길이 :  203

# %%
X = np.array(X)
y = np.array(y)

# %%
n = np.arange(X.shape[0]) # 데이터 셔플링
np.random.seed(0)
np.random.shuffle(n)

# %%
X = X[n]
y = y[n]

# %%
print("Images shape after shuffling = ",X.shape,"\nLabels shape after shuffling = ",y.shape)
# Out:
# Images shape after shuffling =  (11411, 224, 224, 3)
# Labels shape after shuffling =  (11411, 65)

# %%
X = X.astype(np.float32)
y = y.astype(np.int32)
X = X/255.

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.1, random_state=1)

# %%
print("x_train shape = ",x_train.shape)
print("y_train shape = ",y_train.shape)

print("\nx_val shape = ",x_val.shape)
print("y_val shape = ",y_val.shape)

print("\nx_test shape = ",x_test.shape)
print("y_test shape = ",y_test.shape)
# Out:
# x_train shape =  (8215, 224, 224, 3)
# y_train shape =  (8215, 65)
#
# x_val shape =  (913, 224, 224, 3)
# y_val shape =  (913, 65)
#
# x_test shape =  (2283, 224, 224, 3)
# y_test shape =  (2283, 65)

# %%
image_generator = ImageDataGenerator(
    rotation_range = 45,
    width_shift_range = 0.25,
    height_shift_range = 0.25,
    zoom_range = 0.25,
    horizontal_flip=True,
    fill_mode = 'nearest'
)

# %%
image_generator.fit(x_train)

# %%
model=Sequential()

#1 conv layer
model.add(Conv2D(filters=64,kernel_size=(7,7),strides=(3,3),padding="valid",activation="relu",input_shape=(image_w,image_h,3)))

#1 max pool layer
model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
model.add(BatchNormalization())

#2 conv layer
model.add(Conv2D(filters=128,kernel_size=(5,5),strides=(1,1),padding="valid",activation="relu"))

#2 max pool layer
model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
model.add(BatchNormalization())

#3 conv layer
model.add(Conv2D(filters=192,kernel_size=(3,3),strides=(1,1),padding="valid",activation="relu"))

#4 conv layer
model.add(Conv2D(filters=256,kernel_size=(3,3),strides=(1,1),padding="valid",activation="relu"))

#3 max pool layer
model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))

model.add(Flatten())

#1 dense layer
model.add(Dense(2048,input_shape=(image_w,image_h,3),activation="relu"))
model.add(Dropout(0.2))
model.add(BatchNormalization())

#2 dense layer
model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.2))
model.add(BatchNormalization())

#output layer
model.add(Dense(65,activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 73, 73, 64)        9472
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 36, 36, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 36, 36, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 128)       204928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 15, 15, 128)       512
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 192)       221376
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 256)       442624
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              13109248
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2048)              8192
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_2 (Dense)              (None, 65)                66625
# =================================================================
# Total params: 16,165,505
# Trainable params: 16,158,977
# Non-trainable params: 6,528
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
K.set_value(model.optimizer.learning_rate, 0.0001)

# %%
early_stopping= EarlyStopping(monitor='val_loss', mode ='min', verbose = 1, patience = 10)
model_checkPoint = ModelCheckpoint('AlexNet.h5', monitor='val_loss', save_best_only = True, mode ='min', verbose = 1)

# %%
history = model.fit(image_generator.flow(x_train, y_train, batch_size=128), steps_per_epoch=x_train.shape[0]/200, epochs=100, shuffle=True, callbacks=[early_stopping, model_checkPoint], validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 42/41 [==============================] - ETA: -3s - loss: 4.8250 - accuracy: 0.0290
# Epoch 00001: val_loss improved from inf to 4.17843, saving model to AlexNet.h5
# 42/41 [==============================] - 142s 3s/step - loss: 4.8250 - accuracy: 0.0290 - val_loss: 4.1784 - val_accuracy: 0.0318
# Epoch 2/100
# 42/41 [==============================] - ETA: -3s - loss: 4.5303 - accuracy: 0.0366
# Epoch 00002: val_loss did not improve from 4.17843
# 42/41 [==============================] - 141s 3s/step - loss: 4.5303 - accuracy: 0.0366 - val_loss: 4.2538 - val_accuracy: 0.0241
# Epoch 3/100
# 42/41 [==============================] - ETA: -3s - loss: 4.4243 - accuracy: 0.0428
# Epoch 00003: val_loss did not improve from 4.17843
# 42/41 [==============================] - 143s 3s/step - loss: 4.4243 - accuracy: 0.0428 - val_loss: 4.3932 - val_accuracy: 0.0263
# Epoch 4/100
# 42/41 [==============================] - ETA: -3s - loss: 4.3525 - accuracy: 0.0533
# Epoch 00004: val_loss did not improve from 4.17843
# 42/41 [==============================] - 146s 3s/step - loss: 4.3525 - accuracy: 0.0533 - val_loss: 4.4506 - val_accuracy: 0.0274
# Epoch 5/100
# 42/41 [==============================] - ETA: -3s - loss: 4.2758 - accuracy: 0.0571
# Epoch 00005: val_loss did not improve from 4.17843
# 42/41 [==============================] - 144s 3s/step - loss: 4.2758 - accuracy: 0.0571 - val_loss: 4.5424 - val_accuracy: 0.0241
# Epoch 6/100
# 42/41 [==============================] - ETA: -3s - loss: 4.2087 - accuracy: 0.0645
# Epoch 00006: val_loss did not improve from 4.17843
# 42/41 [==============================] - 145s 3s/step - loss: 4.2087 - accuracy: 0.0645 - val_loss: 4.5454 - val_accuracy: 0.0438
# Epoch 7/100
# 42/41 [==============================] - ETA: -3s - loss: 4.1777 - accuracy: 0.0613
# Epoch 00007: val_loss did not improve from 4.17843
# 42/41 [==============================] - 142s 3s/step - loss: 4.1777 - accuracy: 0.0613 - val_loss: 4.5518 - val_accuracy: 0.0350
# Epoch 8/100
# 42/41 [==============================] - ETA: -3s - loss: 4.1581 - accuracy: 0.0632
# Epoch 00008: val_loss did not improve from 4.17843
# 42/41 [==============================] - 142s 3s/step - loss: 4.1581 - accuracy: 0.0632 - val_loss: 4.5284 - val_accuracy: 0.0416
# Epoch 9/100
# 42/41 [==============================] - ETA: -3s - loss: 4.0423 - accuracy: 0.0696
# Epoch 00009: val_loss did not improve from 4.17843
# 42/41 [==============================] - 142s 3s/step - loss: 4.0423 - accuracy: 0.0696 - val_loss: 4.3303 - val_accuracy: 0.0537
# Epoch 10/100
# 42/41 [==============================] - ETA: -3s - loss: 4.0264 - accuracy: 0.0673
# Epoch 00010: val_loss did not improve from 4.17843
# 42/41 [==============================] - 142s 3s/step - loss: 4.0264 - accuracy: 0.0673 - val_loss: 4.1952 - val_accuracy: 0.0460
# Epoch 11/100
# 42/41 [==============================] - ETA: -2s - loss: 3.9893 - accuracy: 0.0787
# Epoch 00011: val_loss improved from 4.17843 to 4.15202, saving model to AlexNet.h5
# 42/41 [==============================] - 140s 3s/step - loss: 3.9893 - accuracy: 0.0787 - val_loss: 4.1520 - val_accuracy: 0.0438
# Epoch 12/100
# 42/41 [==============================] - ETA: -3s - loss: 3.9677 - accuracy: 0.0765
# Epoch 00012: val_loss improved from 4.15202 to 4.05867, saving model to AlexNet.h5
# 42/41 [==============================] - 142s 3s/step - loss: 3.9677 - accuracy: 0.0765 - val_loss: 4.0587 - val_accuracy: 0.0701
# Epoch 13/100
# 42/41 [==============================] - ETA: -3s - loss: 3.9186 - accuracy: 0.0821
# Epoch 00013: val_loss improved from 4.05867 to 3.94267, saving model to AlexNet.h5
# 42/41 [==============================] - 143s 3s/step - loss: 3.9186 - accuracy: 0.0821 - val_loss: 3.9427 - val_accuracy: 0.0843
# Epoch 14/100
# 42/41 [==============================] - ETA: -2s - loss: 3.8705 - accuracy: 0.0913
# Epoch 00014: val_loss improved from 3.94267 to 3.69729, saving model to AlexNet.h5
# 42/41 [==============================] - 139s 3s/step - loss: 3.8705 - accuracy: 0.0913 - val_loss: 3.6973 - val_accuracy: 0.0964
# Epoch 15/100
# 42/41 [==============================] - ETA: -2s - loss: 3.8633 - accuracy: 0.0895
# Epoch 00015: val_loss did not improve from 3.69729
# 42/41 [==============================] - 140s 3s/step - loss: 3.8633 - accuracy: 0.0895 - val_loss: 3.8223 - val_accuracy: 0.0690
# Epoch 16/100
# 42/41 [==============================] - ETA: -2s - loss: 3.8073 - accuracy: 0.1006
# Epoch 00016: val_loss improved from 3.69729 to 3.68940, saving model to AlexNet.h5
# 42/41 [==============================] - 140s 3s/step - loss: 3.8073 - accuracy: 0.1006 - val_loss: 3.6894 - val_accuracy: 0.0964
# Epoch 17/100
# 42/41 [==============================] - ETA: -2s - loss: 3.8049 - accuracy: 0.1004
# Epoch 00017: val_loss improved from 3.68940 to 3.62137, saving model to AlexNet.h5
# 42/41 [==============================] - 139s 3s/step - loss: 3.8049 - accuracy: 0.1004 - val_loss: 3.6214 - val_accuracy: 0.1062
# Epoch 18/100
# 42/41 [==============================] - ETA: -2s - loss: 3.7625 - accuracy: 0.1017
# Epoch 00018: val_loss did not improve from 3.62137
# 42/41 [==============================] - 140s 3s/step - loss: 3.7625 - accuracy: 0.1017 - val_loss: 3.6287 - val_accuracy: 0.1117
# Epoch 19/100
# 42/41 [==============================] - ETA: -2s - loss: 3.7137 - accuracy: 0.0994
# Epoch 00019: val_loss improved from 3.62137 to 3.58091, saving model to AlexNet.h5
# 42/41 [==============================] - 140s 3s/step - loss: 3.7137 - accuracy: 0.0994 - val_loss: 3.5809 - val_accuracy: 0.1139
# Epoch 20/100
# 42/41 [==============================] - ETA: -3s - loss: 3.6976 - accuracy: 0.1099
# Epoch 00020: val_loss improved from 3.58091 to 3.51138, saving model to AlexNet.h5
# 42/41 [==============================] - 142s 3s/step - loss: 3.6976 - accuracy: 0.1099 - val_loss: 3.5114 - val_accuracy: 0.1030
# Epoch 21/100
# 42/41 [==============================] - ETA: -2s - loss: 3.6594 - accuracy: 0.1148
# Epoch 00021: val_loss did not improve from 3.51138
# 42/41 [==============================] - 139s 3s/step - loss: 3.6594 - accuracy: 0.1148 - val_loss: 3.7264 - val_accuracy: 0.0909
# Epoch 22/100
# 42/41 [==============================] - ETA: -2s - loss: 3.6121 - accuracy: 0.1203
# Epoch 00022: val_loss improved from 3.51138 to 3.47769, saving model to AlexNet.h5
# 42/41 [==============================] - 139s 3s/step - loss: 3.6121 - accuracy: 0.1203 - val_loss: 3.4777 - val_accuracy: 0.1490
# Epoch 23/100
# 42/41 [==============================] - ETA: -2s - loss: 3.6088 - accuracy: 0.1252
# Epoch 00023: val_loss did not improve from 3.47769
# 42/41 [==============================] - 139s 3s/step - loss: 3.6088 - accuracy: 0.1252 - val_loss: 4.3682 - val_accuracy: 0.1051
# Epoch 24/100
# 42/41 [==============================] - ETA: -2s - loss: 3.5421 - accuracy: 0.1313
# Epoch 00024: val_loss did not improve from 3.47769
# 42/41 [==============================] - 140s 3s/step - loss: 3.5421 - accuracy: 0.1313 - val_loss: 3.8479 - val_accuracy: 0.1260
# Epoch 25/100
# 42/41 [==============================] - ETA: -2s - loss: 3.5240 - accuracy: 0.1349
# Epoch 00025: val_loss did not improve from 3.47769
# 42/41 [==============================] - 139s 3s/step - loss: 3.5240 - accuracy: 0.1349 - val_loss: 4.3095 - val_accuracy: 0.1084
# Epoch 26/100
# 42/41 [==============================] - ETA: -2s - loss: 3.5274 - accuracy: 0.1324
# Epoch 00026: val_loss improved from 3.47769 to 3.44916, saving model to AlexNet.h5
# 42/41 [==============================] - 140s 3s/step - loss: 3.5274 - accuracy: 0.1324 - val_loss: 3.4492 - val_accuracy: 0.1402
# Epoch 27/100
# 42/41 [==============================] - ETA: -2s - loss: 3.4933 - accuracy: 0.1355
# Epoch 00027: val_loss improved from 3.44916 to 3.37211, saving model to AlexNet.h5
# 42/41 [==============================] - 140s 3s/step - loss: 3.4933 - accuracy: 0.1355 - val_loss: 3.3721 - val_accuracy: 0.1665
# Epoch 28/100
# 42/41 [==============================] - ETA: -3s - loss: 3.4426 - accuracy: 0.1525
# Epoch 00028: val_loss improved from 3.37211 to 3.32601, saving model to AlexNet.h5
# 42/41 [==============================] - 142s 3s/step - loss: 3.4426 - accuracy: 0.1525 - val_loss: 3.3260 - val_accuracy: 0.1665
# Epoch 29/100
# 42/41 [==============================] - ETA: -3s - loss: 3.3996 - accuracy: 0.1557
# Epoch 00029: val_loss did not improve from 3.32601
# 42/41 [==============================] - 143s 3s/step - loss: 3.3996 - accuracy: 0.1557 - val_loss: 3.7750 - val_accuracy: 0.0975
# Epoch 30/100
# 42/41 [==============================] - ETA: -2s - loss: 3.3437 - accuracy: 0.1586
# Epoch 00030: val_loss did not improve from 3.32601
# 42/41 [==============================] - 139s 3s/step - loss: 3.3437 - accuracy: 0.1586 - val_loss: 3.3816 - val_accuracy: 0.1533
# Epoch 31/100
# 42/41 [==============================] - ETA: -2s - loss: 3.3805 - accuracy: 0.1527
# Epoch 00031: val_loss did not improve from 3.32601
# 42/41 [==============================] - 139s 3s/step - loss: 3.3805 - accuracy: 0.1527 - val_loss: 3.7732 - val_accuracy: 0.1095
# Epoch 32/100
# 42/41 [==============================] - ETA: -2s - loss: 3.3480 - accuracy: 0.1558
# Epoch 00032: val_loss improved from 3.32601 to 3.17619, saving model to AlexNet.h5
# 42/41 [==============================] - 140s 3s/step - loss: 3.3480 - accuracy: 0.1558 - val_loss: 3.1762 - val_accuracy: 0.2114
# Epoch 33/100
# 42/41 [==============================] - ETA: -2s - loss: 3.2780 - accuracy: 0.1726
# Epoch 00033: val_loss did not improve from 3.17619
# 42/41 [==============================] - 139s 3s/step - loss: 3.2780 - accuracy: 0.1726 - val_loss: 3.3216 - val_accuracy: 0.1807
# Epoch 34/100
# 42/41 [==============================] - ETA: -3s - loss: 3.2393 - accuracy: 0.1756
# Epoch 00034: val_loss did not improve from 3.17619
# 42/41 [==============================] - 141s 3s/step - loss: 3.2393 - accuracy: 0.1756 - val_loss: 3.2674 - val_accuracy: 0.1785
# Epoch 35/100
# 42/41 [==============================] - ETA: -2s - loss: 3.2220 - accuracy: 0.1846
# Epoch 00035: val_loss did not improve from 3.17619
# 42/41 [==============================] - 139s 3s/step - loss: 3.2220 - accuracy: 0.1846 - val_loss: 3.2808 - val_accuracy: 0.1928
# Epoch 36/100
# 42/41 [==============================] - ETA: -2s - loss: 3.2186 - accuracy: 0.1793
# Epoch 00036: val_loss did not improve from 3.17619
# 42/41 [==============================] - 139s 3s/step - loss: 3.2186 - accuracy: 0.1793 - val_loss: 3.1902 - val_accuracy: 0.1698
# Epoch 37/100
# 42/41 [==============================] - ETA: -3s - loss: 3.1795 - accuracy: 0.1834
# Epoch 00037: val_loss did not improve from 3.17619
# 42/41 [==============================] - 142s 3s/step - loss: 3.1795 - accuracy: 0.1834 - val_loss: 3.1950 - val_accuracy: 0.1862
# Epoch 38/100
# 42/41 [==============================] - ETA: -2s - loss: 3.1949 - accuracy: 0.1876
# Epoch 00038: val_loss did not improve from 3.17619
# 42/41 [==============================] - 139s 3s/step - loss: 3.1949 - accuracy: 0.1876 - val_loss: 3.3728 - val_accuracy: 0.1599
# Epoch 39/100
# 42/41 [==============================] - ETA: -2s - loss: 3.1333 - accuracy: 0.1994
# Epoch 00039: val_loss did not improve from 3.17619
# 42/41 [==============================] - 139s 3s/step - loss: 3.1333 - accuracy: 0.1994 - val_loss: 5.2429 - val_accuracy: 0.1205
# Epoch 40/100
# 42/41 [==============================] - ETA: -2s - loss: 3.0804 - accuracy: 0.2102
# Epoch 00040: val_loss did not improve from 3.17619
# 42/41 [==============================] - 139s 3s/step - loss: 3.0804 - accuracy: 0.2102 - val_loss: 3.3251 - val_accuracy: 0.1698
# Epoch 41/100
# 42/41 [==============================] - ETA: -2s - loss: 3.0897 - accuracy: 0.1952
# Epoch 00041: val_loss did not improve from 3.17619
# 42/41 [==============================] - 139s 3s/step - loss: 3.0897 - accuracy: 0.1952 - val_loss: 3.6372 - val_accuracy: 0.1369
# Epoch 42/100
# 42/41 [==============================] - ETA: -3s - loss: 3.0722 - accuracy: 0.2106
# Epoch 00042: val_loss did not improve from 3.17619
# 42/41 [==============================] - 141s 3s/step - loss: 3.0722 - accuracy: 0.2106 - val_loss: 3.2229 - val_accuracy: 0.2333
# Epoch 00042: early stopping

# %%
model.load_weights('AlexNet.h5')

# %%
loss, accuracy = model.evaluate(x_test, y_test)

print('\nLoss: {:.4f}, Acc: {:.4f}'.format(loss, accuracy))
# Out:
# 72/72 [==============================] - 13s 183ms/step - loss: 3.2498 - accuracy: 0.1831
#
# Loss: 3.2498, Acc: 0.1831

# %%
def plot_loss(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc=0)

def plot_acc(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc=0)

# %%
plot_loss(history)
plt.show()

# %%
plot_acc(history)
plt.show()

# %%
predictions = model.predict(x_test)

# %%
plt.figure(1 , figsize = (19 , 10))
n = 0 

for i in range(16):
    n += 1 
    r = np.random.randint( 0, x_test.shape[0], 1)
    
    plt.subplot(4, 4, n)
    plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
    
    plt.imshow(x_test[r[0]])
    plt.title('Actual = {}, \nPredicted = {}'.format(categories[np.argpartition(y_test[r[0]],-1)[-1:][0]] , categories[np.argpartition(predictions[r[0]][y_test[r[0]]],-1)[-1:][0]]))
    plt.xticks([]) , plt.yticks([])

plt.show()

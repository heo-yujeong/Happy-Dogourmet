# %% [markdown]
# https://dataplay.tistory.com/27

# %% [markdown]
# # - ResNet(ResNet50)

# %% [markdown]
# https://eremo2002.tistory.com/76

# %%
import os, glob
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from sklearn.model_selection import train_test_split

from tensorflow.keras import Input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import BatchNormalization, Conv2D, Activation, Dense, GlobalAveragePooling2D, MaxPooling2D, ZeroPadding2D, Add
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img_dir = 'data/Images3'
categories = os.listdir(img_dir)
num_classes = len(categories)

# %%
image_w = 224
image_h = 224

# %%
X = []
y = []

for index, breed in enumerate(categories):
    label = [0 for i in range(num_classes)]
    label[index] = 1

    image_dir = img_dir + "/" + breed
    files = glob.glob(image_dir+"/*.jpg")
    print(index, ")", breed, " 파일 길이 : ", len(files))
    for i, f in enumerate(files):
        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((image_w, image_h))
        data = np.asarray(img)

        X.append(data)
        y.append(label)
# Out:
# 0 ) n02085620-Chihuahua  파일 길이 :  152
# 1 ) n02085782-Japanese_spaniel  파일 길이 :  185
# 2 ) n02085936-Maltese_dog  파일 길이 :  252
# 3 ) n02086079-Pekinese  파일 길이 :  149
# 4 ) n02086240-Shih-Tzu  파일 길이 :  214
# 5 ) n02086646-Blenheim_spaniel  파일 길이 :  188
# 6 ) n02086910-papillon  파일 길이 :  196
# 7 ) n02088364-beagle  파일 길이 :  195
# 8 ) n02088466-bloodhound  파일 길이 :  187
# 9 ) n02089078-black-and-tan_coonhound  파일 길이 :  159
# 10 ) n02089867-Walker_hound  파일 길이 :  153
# 11 ) n02089973-English_foxhound  파일 길이 :  157
# 12 ) n02091032-Italian_greyhound  파일 길이 :  182
# 13 ) n02091134-whippet  파일 길이 :  187
# 14 ) n02093256-Staffordshire_bullterrier  파일 길이 :  155
# 15 ) n02093647-Bedlington_terrier  파일 길이 :  182
# 16 ) n02094258-Norwich_terrier  파일 길이 :  185
# 17 ) n02094433-Yorkshire_terrier  파일 길이 :  164
# 18 ) n02096294-Australian_terrier  파일 길이 :  196
# 19 ) n02096585-Boston_bull  파일 길이 :  182
# 20 ) n02097047-miniature_schnauzer  파일 길이 :  154
# 21 ) n02097209-standard_schnauzer  파일 길이 :  155
# 22 ) n02097658-silky_terrier  파일 길이 :  183
# 23 ) n02098286-West_Highland_white_terrier  파일 길이 :  169
# 24 ) n02098413-Lhasa  파일 길이 :  186
# 25 ) n02099601-golden_retriever  파일 길이 :  150
# 26 ) n02099712-Labrador_retriever  파일 길이 :  171
# 27 ) n02100583-vizsla  파일 길이 :  154
# 28 ) n02100735-English_setter  파일 길이 :  161
# 29 ) n02102177-Welsh_springer_spaniel  파일 길이 :  150
# 30 ) n02102318-cocker_spaniel  파일 길이 :  159
# 31 ) n02104029-kuvasz  파일 길이 :  150
# 32 ) n02105162-malinois  파일 길이 :  150
# 33 ) n02105855-Shetland_sheepdog  파일 길이 :  157
# 34 ) n02106030-collie  파일 길이 :  153
# 35 ) n02106166-Border_collie  파일 길이 :  150
# 36 ) n02106550-Rottweiler  파일 길이 :  152
# 37 ) n02106662-German_shepherd  파일 길이 :  152
# 38 ) n02107142-Doberman  파일 길이 :  150
# 39 ) n02107312-miniature_pinscher  파일 길이 :  184
# 40 ) n02108089-boxer  파일 길이 :  151
# 41 ) n02108551-Tibetan_mastiff  파일 길이 :  152
# 42 ) n02108915-French_bulldog  파일 길이 :  159
# 43 ) n02109047-Great_Dane  파일 길이 :  156
# 44 ) n02109525-Saint_Bernard  파일 길이 :  170
# 45 ) n02109961-Eskimo_dog  파일 길이 :  150
# 46 ) n02110063-malamute  파일 길이 :  178
# 47 ) n02110185-Siberian_husky  파일 길이 :  192
# 48 ) n02110958-pug  파일 길이 :  200
# 49 ) n02111889-Samoyed  파일 길이 :  218
# 50 ) n02112018-Pomeranian  파일 길이 :  219
# 51 ) n02112137-chow  파일 길이 :  196
# 52 ) n02113023-Pembroke  파일 길이 :  181
# 53 ) n02113186-Cardigan  파일 길이 :  155
# 54 ) n02113624-toy_poodle  파일 길이 :  151
# 55 ) n02113712-miniature_poodle  파일 길이 :  155
# 56 ) n02113799-standard_poodle  파일 길이 :  159
# 57 ) n02113980-bichon_frise  파일 길이 :  231
# 58 ) n02113981-shiba_inu  파일 길이 :  225
# 59 ) n02113982-cane_corso  파일 길이 :  224
# 60 ) n02113983-miniature_dachshund  파일 길이 :  162
# 61 ) n02113984-akita  파일 길이 :  217
# 62 ) n02113985-jindodog  파일 길이 :  186
# 63 ) n02113986-coton_de_tulear  파일 길이 :  211
# 64 ) n02113987-spitz  파일 길이 :  203

# %%
X = np.array(X)
y = np.array(y)

# %%
n = np.arange(X.shape[0])
np.random.seed(0)
np.random.shuffle(n)

# %%
X = X[n]
y = y[n]

# %%
print("Images shape after shuffling = ",X.shape,"\nLabels shape after shuffling = ",y.shape)
# Out:
# Images shape after shuffling =  (11411, 224, 224, 3)
# Labels shape after shuffling =  (11411, 65)

# %%
X = X.astype(np.float32)
y = y.astype(np.int32)
X = X/255.

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.1, random_state=1)

# %%
print("x_train shape = ",x_train.shape)
print("y_train shape = ",y_train.shape)

print("\nx_val shape = ",x_val.shape)
print("y_val shape = ",y_val.shape)

print("\nx_test shape = ",x_test.shape)
print("y_test shape = ",y_test.shape)
# Out:
# x_train shape =  (8215, 224, 224, 3)
# y_train shape =  (8215, 65)
#
# x_val shape =  (913, 224, 224, 3)
# y_val shape =  (913, 65)
#
# x_test shape =  (2283, 224, 224, 3)
# y_test shape =  (2283, 65)

# %%
image_generator = ImageDataGenerator(
    rotation_range = 45,
    width_shift_range = 0.25,
    height_shift_range = 0.25,
    zoom_range = 0.25,
    horizontal_flip=True,
    fill_mode = 'nearest'
)

# %%
image_generator.fit(x_train)

# %%
def conv1_layer(x):    
    x = ZeroPadding2D(padding=(3, 3))(x)
    x = Conv2D(32, (5, 5), strides=(2, 2))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = ZeroPadding2D(padding=(1,1))(x)
    return x

# %%
def conv2_layer(x):         
    x = MaxPooling2D((3, 3), 2)(x)
    shortcut = x
 
    for i in range(2):
        if (i == 0):
            x = Conv2D(32, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
            shortcut = Conv2D(64, (3, 3), strides=(1, 1), padding='same')(shortcut)            
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)
 
            x = Add()([x, shortcut])
            x = Activation('relu')(x)
            
            shortcut = x
 
        else:
            x = Conv2D(32, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])   
            x = Activation('relu')(x)  
 
            shortcut = x        
    
    return x

# %%
def conv3_layer(x):        
    shortcut = x    
    
    for i in range(2):     
        if(i == 0):            
            x = Conv2D(64, (1, 1), strides=(2, 2), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        
 
            x = Conv2D(128, (1, 1), strides=(1, 1), padding='same')(x)
            shortcut = Conv2D(128, (3, 3), strides=(2, 2), padding='same')(shortcut)
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)            
 
            x = Add()([x, shortcut])    
            x = Activation('relu')(x)    
 
            shortcut = x              
        
        else:
            x = Conv2D(64, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])     
            x = Activation('relu')(x)
 
            shortcut = x      
            
    return x

# %%
def conv4_layer(x):
    shortcut = x        
  
    for i in range(2):     
        if(i == 0):            
            x = Conv2D(128, (1, 1), strides=(2, 2), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        

            x = Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
            shortcut = Conv2D(256, (1, 1), strides=(2, 2), padding='same')(shortcut)
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)
 
            x = Add()([x, shortcut]) 
            x = Activation('relu')(x)
 
            shortcut = x               
        
        else:
            x = Conv2D(128, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)

            x = Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])    
            x = Activation('relu')(x)
 
            shortcut = x      
 
    return x

# %%
input_tensor = Input(shape=(image_w, image_h, 3), name='input')
x = conv1_layer(input_tensor)
x = conv2_layer(x)
x = conv3_layer(x)
x = conv4_layer(x)
 
x = GlobalAveragePooling2D()(x)
output_tensor = Dense(num_classes, activation='softmax')(x)
 
model = Model(input_tensor, output_tensor)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0           input[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 113, 113, 32) 2432        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 113, 113, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 113, 113, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 115, 115, 32) 0           activation[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 57, 57, 32)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 57, 57, 32)   1056        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 57, 57, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 57, 57, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 57, 57, 64)   18496       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 57, 57, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 57, 57, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 57, 57, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 57, 57, 64)   0           batch_normalization_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 57, 57, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 57, 57, 32)   2080        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 57, 57, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 57, 57, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 57, 57, 64)   18496       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 57, 57, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 57, 57, 64)   0           batch_normalization_5[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 57, 57, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 29, 29, 64)   4160        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 29, 29, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 29, 29, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 29, 29, 128)  8320        activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 29, 29, 128)  73856       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 29, 29, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 29, 29, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 29, 29, 128)  0           batch_normalization_7[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 29, 29, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 29, 29, 64)   8256        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 29, 29, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 29, 29, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 29, 29, 128)  73856       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 29, 29, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 29, 29, 128)  0           batch_normalization_10[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 29, 29, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 15, 15, 128)  16512       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 15, 15, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 15, 15, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 15, 15, 256)  295168      activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 15, 15, 256)  33024       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 15, 15, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 15, 15, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 15, 15, 256)  0           batch_normalization_12[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 15, 15, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 15, 15, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 15, 15, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 15, 15, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 15, 15, 256)  295168      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 15, 15, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 15, 15, 256)  0           batch_normalization_15[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 15, 15, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           activation_12[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 65)           16705       global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 926,273
# Trainable params: 922,625
# Non-trainable params: 3,648
# __________________________________________________________________________________________________

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
K.set_value(model.optimizer.learning_rate, 0.0001)

# %%
early_stopping= EarlyStopping(monitor='val_loss', mode ='min', verbose = 1, patience = 10)
model_checkPoint = ModelCheckpoint('ResNet.h5', monitor='val_loss', save_best_only = True, mode ='min', verbose = 1)

# %%
history = model.fit(image_generator.flow(x_train, y_train, batch_size=128), steps_per_epoch=x_train.shape[0]/200, epochs=100, shuffle=True, callbacks=[early_stopping, model_checkPoint], validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 42/41 [==============================] - ETA: -7s - loss: 4.3554 - accuracy: 0.0279
# Epoch 00001: val_loss improved from inf to 4.17892, saving model to ResNet.h5
# 42/41 [==============================] - 334s 8s/step - loss: 4.3554 - accuracy: 0.0279 - val_loss: 4.1789 - val_accuracy: 0.0153
# Epoch 2/100
# 42/41 [==============================] - ETA: -7s - loss: 4.0351 - accuracy: 0.0508
# Epoch 00002: val_loss did not improve from 4.17892
# 42/41 [==============================] - 329s 8s/step - loss: 4.0351 - accuracy: 0.0508 - val_loss: 4.2049 - val_accuracy: 0.0263
# Epoch 3/100
# 42/41 [==============================] - ETA: -6s - loss: 3.9297 - accuracy: 0.0673
# Epoch 00003: val_loss did not improve from 4.17892
# 42/41 [==============================] - 320s 8s/step - loss: 3.9297 - accuracy: 0.0673 - val_loss: 4.2815 - val_accuracy: 0.0307
# Epoch 4/100
# 42/41 [==============================] - ETA: -6s - loss: 3.8755 - accuracy: 0.0749
# Epoch 00004: val_loss did not improve from 4.17892
# 42/41 [==============================] - 321s 8s/step - loss: 3.8755 - accuracy: 0.0749 - val_loss: 4.4279 - val_accuracy: 0.0252
# Epoch 5/100
# 42/41 [==============================] - ETA: -6s - loss: 3.8252 - accuracy: 0.0861
# Epoch 00005: val_loss did not improve from 4.17892
# 42/41 [==============================] - 322s 8s/step - loss: 3.8252 - accuracy: 0.0861 - val_loss: 4.6835 - val_accuracy: 0.0307
# Epoch 6/100
# 42/41 [==============================] - ETA: -6s - loss: 3.7595 - accuracy: 0.0968
# Epoch 00006: val_loss did not improve from 4.17892
# 42/41 [==============================] - 320s 8s/step - loss: 3.7595 - accuracy: 0.0968 - val_loss: 5.1054 - val_accuracy: 0.0263
# Epoch 7/100
# 42/41 [==============================] - ETA: -7s - loss: 3.7485 - accuracy: 0.0952
# Epoch 00007: val_loss did not improve from 4.17892
# 42/41 [==============================] - 328s 8s/step - loss: 3.7485 - accuracy: 0.0952 - val_loss: 5.2596 - val_accuracy: 0.0208
# Epoch 8/100
# 42/41 [==============================] - ETA: -6s - loss: 3.6863 - accuracy: 0.1011
# Epoch 00008: val_loss did not improve from 4.17892
# 42/41 [==============================] - 324s 8s/step - loss: 3.6863 - accuracy: 0.1011 - val_loss: 5.2936 - val_accuracy: 0.0340
# Epoch 9/100
# 42/41 [==============================] - ETA: -6s - loss: 3.6668 - accuracy: 0.1205
# Epoch 00009: val_loss did not improve from 4.17892
# 42/41 [==============================] - 326s 8s/step - loss: 3.6668 - accuracy: 0.1205 - val_loss: 5.3603 - val_accuracy: 0.0307
# Epoch 10/100
# 42/41 [==============================] - ETA: -6s - loss: 3.6235 - accuracy: 0.1246
# Epoch 00010: val_loss did not improve from 4.17892
# 42/41 [==============================] - 322s 8s/step - loss: 3.6235 - accuracy: 0.1246 - val_loss: 5.5626 - val_accuracy: 0.0263
# Epoch 11/100
# 42/41 [==============================] - ETA: -6s - loss: 3.5928 - accuracy: 0.1239
# Epoch 00011: val_loss did not improve from 4.17892
# 42/41 [==============================] - 320s 8s/step - loss: 3.5928 - accuracy: 0.1239 - val_loss: 4.7605 - val_accuracy: 0.0394
# Epoch 00011: early stopping

# %%
model.load_weights('ResNet.h5')

# %%
loss, accuracy = model.evaluate(x_test, y_test)

print('\nLoss: {:.4f}, Acc: {:.4f}'.format(loss, accuracy))
# Out:
# 72/72 [==============================] - 27s 369ms/step - loss: 4.1751 - accuracy: 0.0162
#
# Loss: 4.1751, Acc: 0.0162

# %%
def plot_loss(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc=0)

def plot_acc(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc=0)

# %%
plot_loss(history)
plt.show()

# %%
plot_acc(history)
plt.show()

# %%
predictions = model.predict(x_test)

# %%
plt.figure(1 , figsize = (19 , 10))
n = 0 

for i in range(16):
    n += 1 
    r = np.random.randint( 0, x_test.shape[0], 1)
    
    plt.subplot(4, 4, n)
    plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
    
    plt.imshow(x_test[r[0]])
    plt.title('Actual = {} \nPredicted = {}'.format(categories[np.argpartition(y_test[r[0]],-1)[-1:][0]] , categories[np.argpartition(predictions[r[0]][y_test[r[0]]],-1)[-1:][0]]))
    plt.xticks([]) , plt.yticks([])

plt.show()
